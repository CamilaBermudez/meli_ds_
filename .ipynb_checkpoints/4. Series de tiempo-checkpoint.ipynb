# %%
# !pip install skforecast
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting skforecast
#   Using cached skforecast-0.6.0-py2.py3-none-any.whl (216 kB)
# Requirement already satisfied: tqdm<4.65,>=4.57.0 in c:\programdata\anaconda3\lib\site-packages (from skforecast) (4.64.1)
# Requirement already satisfied: pandas<1.6,>=1.2 in c:\programdata\anaconda3\lib\site-packages (from skforecast) (1.4.4)
# Requirement already satisfied: scikit-learn<1.2,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from skforecast) (1.0.2)
# Collecting optuna<3.1,>=2.10.0
#   Using cached optuna-3.0.5-py3-none-any.whl (348 kB)
# Requirement already satisfied: numpy<1.24,>=1.20 in c:\programdata\anaconda3\lib\site-packages (from skforecast) (1.21.5)
# Collecting scikit-optimize==0.9.0
#   Using cached scikit_optimize-0.9.0-py2.py3-none-any.whl (100 kB)
# Requirement already satisfied: joblib<1.3.0,>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from skforecast) (1.1.0)
# Collecting pyaml>=16.9
#   Using cached pyaml-21.10.1-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: scipy>=0.19.1 in c:\programdata\anaconda3\lib\site-packages (from scikit-optimize==0.9.0->skforecast) (1.9.1)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from optuna<3.1,>=2.10.0->skforecast) (21.3)
# Collecting cmaes>=0.8.2
#   Using cached cmaes-0.9.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: PyYAML in c:\programdata\anaconda3\lib\site-packages (from optuna<3.1,>=2.10.0->skforecast) (6.0)
# Collecting scipy>=0.19.1
#   Downloading scipy-1.8.1-cp39-cp39-win_amd64.whl (36.9 MB)
#      ---------------------------------------- 36.9/36.9 MB 3.9 MB/s eta 0:00:00
# Collecting alembic>=1.5.0
#   Using cached alembic-1.9.4-py3-none-any.whl (210 kB)
# Collecting cliff
#   Using cached cliff-4.2.0-py3-none-any.whl (81 kB)
# Requirement already satisfied: importlib-metadata<5.0.0 in c:\programdata\anaconda3\lib\site-packages (from optuna<3.1,>=2.10.0->skforecast) (4.11.3)
# Requirement already satisfied: sqlalchemy>=1.3.0 in c:\programdata\anaconda3\lib\site-packages (from optuna<3.1,>=2.10.0->skforecast) (1.4.39)
# Collecting colorlog
#   Using cached colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas<1.6,>=1.2->skforecast) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\lib\site-packages (from pandas<1.6,>=1.2->skforecast) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn<1.2,>=1.0->skforecast) (2.2.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm<4.65,>=4.57.0->skforecast) (0.4.5)
# Collecting Mako
#   Using cached Mako-1.2.4-py3-none-any.whl (78 kB)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata<5.0.0->optuna<3.1,>=2.10.0->skforecast) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging>=20.0->optuna<3.1,>=2.10.0->skforecast) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas<1.6,>=1.2->skforecast) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\programdata\anaconda3\lib\site-packages (from sqlalchemy>=1.3.0->optuna<3.1,>=2.10.0->skforecast) (1.1.1)
# Collecting PrettyTable>=0.7.2
#   Using cached prettytable-3.6.0-py3-none-any.whl (27 kB)
# Collecting autopage>=0.4.0
#   Using cached autopage-0.5.1-py3-none-any.whl (29 kB)
# Collecting stevedore>=2.0.1
#   Using cached stevedore-5.0.0-py3-none-any.whl (49 kB)
# Collecting cmd2>=1.0.0
#   Using cached cmd2-2.4.3-py3-none-any.whl (147 kB)
# Collecting pyperclip>=1.6
#   Using cached pyperclip-1.8.2.tar.gz (20 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: attrs>=16.3.0 in c:\programdata\anaconda3\lib\site-packages (from cmd2>=1.0.0->cliff->optuna<3.1,>=2.10.0->skforecast) (21.4.0)
# Collecting pyreadline3
#   Using cached pyreadline3-3.4.1-py3-none-any.whl (95 kB)
# Requirement already satisfied: wcwidth>=0.1.7 in c:\programdata\anaconda3\lib\site-packages (from cmd2>=1.0.0->cliff->optuna<3.1,>=2.10.0->skforecast) (0.2.5)
# Collecting pbr!=2.1.0,>=2.0.0
#   Using cached pbr-5.11.1-py2.py3-none-any.whl (112 kB)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\programdata\anaconda3\lib\site-packages (from Mako->alembic>=1.5.0->optuna<3.1,>=2.10.0->skforecast) (2.0.1)
# Building wheels for collected packages: pyperclip
#   Building wheel for pyperclip (setup.py): started
#   Building wheel for pyperclip (setup.py): finished with status 'done'
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11123 sha256=17b24d06e3a7d7f6d55eeaaf2be7cc214847f23a444b68e70d4ee4cb9b0164d4
#   Stored in directory: c:\users\camila bermudez\appdata\local\pip\cache\wheels\0c\09\9e\49e21a6840ef7955b06d47394afef0058f0378c0914e48b8b8
# Successfully built pyperclip
# Installing collected packages: pyreadline3, pyperclip, scipy, pyaml, PrettyTable, pbr, Mako, colorlog, cmd2, cmaes, autopage, stevedore, alembic, scikit-optimize, cliff, optuna, skforecast
# Successfully installed Mako-1.2.4 PrettyTable-3.6.0 alembic-1.9.4 autopage-0.5.1 cliff-4.2.0 cmaes-0.9.1 cmd2-2.4.3 colorlog-6.7.0 optuna-3.0.5 pbr-5.11.1 pyaml-21.10.1 pyperclip-1.8.2 pyreadline3-3.4.1 scikit-optimize-0.9.0 scipy-1.8.1 skforecast-0.6.0 stevedore-5.0.0
#   WARNING: The script pbr.exe is installed in 'C:\Users\Camila Bermudez\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script mako-render.exe is installed in 'C:\Users\Camila Bermudez\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script alembic.exe is installed in 'C:\Users\Camila Bermudez\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script optuna.exe is installed in 'C:\Users\Camila Bermudez\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
from  matplotlib import pyplot
import math
from datetime import datetime
from datetime import date
from skforecast.ForecasterAutoreg import ForecasterAutoreg
from sklearn.ensemble import RandomForestRegressor
from skforecast.model_selection import grid_search_forecaster
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from datetime import timedelta

# %%
df = pd.read_csv("series.csv")

# %%
df.shape
# Out:
# (2686, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2686 entries, 0 to 2685
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CATEGORY    2686 non-null   object
#  1   DATE        2686 non-null   object
#  2   UNITS_SOLD  2686 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 63.1+ KB

# %%
df['DATE']= pd.to_datetime(df['DATE'],format="%Y-%m-%d")

# %%
df.head()
# Out:
#   CATEGORY       DATE  UNITS_SOLD
# 0  CATEG-1 2021-08-17          59
# 1  CATEG-1 2020-09-19          40
# 2  CATEG-2 2021-10-26          23
# 3  CATEG-1 2021-04-27          60
# 4  CATEG-2 2021-05-05          61

# %%
df.groupby('CATEGORY').describe()
# Out:
#          UNITS_SOLD                                                       \
#               count         mean         std  min    25%     50%     75%
# CATEGORY
# CATEG-1       887.0    53.130778   31.921476  1.0   31.0    47.0    65.0
# CATEG-2       879.0    44.747440   59.467396  1.0    9.0    19.0    51.5
# CATEG-3       920.0  1457.304348  869.635335  0.0  675.0  1452.0  2015.0
#
#
#              max
# CATEGORY
# CATEG-1    210.0
# CATEG-2    332.0
# CATEG-3   7551.0

# %%
df.groupby('CATEGORY').DATE.agg(['min','max'])
# Out:
#                 min        max
# CATEGORY
# CATEG-1  2018-10-16 2021-11-12
# CATEG-2  2018-10-16 2021-11-12
# CATEG-3  2018-09-24 2021-11-12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2686 entries, 0 to 2685
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CATEGORY    2686 non-null   object
#  1   DATE        2686 non-null   datetime64[ns]
#  2   UNITS_SOLD  2686 non-null   int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 63.1+ KB

# %%
df.set_index('DATE',inplace=True,drop=True)
df['UNITS_SOLD']= df['UNITS_SOLD'].astype(np.int32)

# %%
df_1 = df[df.CATEGORY=='CATEG-1'][['UNITS_SOLD']]
df_2 = df[df.CATEGORY=='CATEG-2'][['UNITS_SOLD']]
df_3 = df[df.CATEGORY=='CATEG-3'][['UNITS_SOLD']]

# %% [markdown]
# ### CATEG-1

# %%
df_1 = df_1.sort_index(ascending=True)

# %%
df_1.shape
# Out:
# (887, 1)

# %%
df_1.head(10)
# Out:
#             UNITS_SOLD
# DATE
# 2018-10-16           1
# 2019-06-11          27
# 2019-06-12          26
# 2019-06-13          24
# 2019-06-14          18
# 2019-06-15          15
# 2019-06-16          11
# 2019-06-17          22
# 2019-06-18          19
# 2019-06-19          22

# %%
df_1.tail(10)
# Out:
#             UNITS_SOLD
# DATE
# 2021-11-03          36
# 2021-11-04          52
# 2021-11-05          62
# 2021-11-06          54
# 2021-11-07          46
# 2021-11-08          63
# 2021-11-09          65
# 2021-11-10         189
# 2021-11-11         194
# 2021-11-12         146

# %% [markdown]
# Como podemos ver en las 10 primeras observaciones de la serie, hay una observación del 2018-10-16 y puego la serie sigue diaria despues del 2019-06-11, luego quitamos la primera observación.

# %%
df_1 = df_1.loc['2019-06-11':'2021-11-12']
df_1.shape
# Out:
# (886, 1)

# %%
df_1.set_index(df_1.resample('D').mean().index,inplace=True,drop=True)

# %% [markdown]
# Comprobamos que la longitud de la serie coincida con la cantidad de dias entre las fechas de inicio y final de la misma

# %%
f_date = date(2019, 6, 11)
l_date = date(2021, 11, 12)
delta = l_date - f_date
print(delta.days)
# Out:
# 885

# %% [markdown]
# Graficamos la serie para evidenciar estacionalidades

# %%
plt.plot(df_1.UNITS_SOLD)

# %% [markdown]
# Graficamos la primera de la serie y parece quedar con una media constante pero la varianza no lo es

# %%
plt.plot(df_1.UNITS_SOLD-df_1.UNITS_SOLD.shift(1))

# %% [markdown]
# Graficamos el autocorrelograma y el autocorrelograma parcial para identificar si es un proceso ARMA

# %%
plot_acf(df_1)
pyplot.show()

# %%
plot_pacf(df_1, lags=30)
pyplot.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# Hacemos la partición de la serie, para estimar los ultimos 120 dias

# %%
steps = 120
data_train = df_1[:-steps]
data_test  = df_1[-steps:]

print(f"Train dates : {data_train.index.min()} --- {data_train.index.max()}  (n={len(data_train)})")
print(f"Test dates  : {data_test.index.min()} --- {data_test.index.max()}  (n={len(data_test)})")

fig, ax=plt.subplots(figsize=(9, 4))
data_train['UNITS_SOLD'].plot(ax=ax, label='train')
data_test['UNITS_SOLD'].plot(ax=ax, label='test')
ax.legend();
# Out:
# Train dates : 2019-06-11 00:00:00 --- 2021-07-15 00:00:00  (n=766)
# Test dates  : 2021-07-16 00:00:00 --- 2021-11-12 00:00:00  (n=120)

# %% [markdown]
# Según lo que vimos anteriormente se necesita 1 diferencia para que el proceso se aproxime a ser estacionario y según los autocorrelogramas vemos que es un proceso aurotegresivo. En las graficas se ve que mas o menos cada 6 meses hay unos picos, luego ajustamos la estacionalidad a 180 dias.

# %%
SARIMAmodel = SARIMAX(data_train, order = (1, 1, 0), seasonal_order=(1,1,0,180)) 
SARIMAmodel = SARIMAmodel.fit()

# %% [markdown]
# Hacemos el predict sobre los 120 dias que definimos anteriormente + 21 dias adicionales que son las predicciones solicitadas.

# %%
y_pred = SARIMAmodel.get_forecast(len(data_test.index)+21)
y_pred_df = y_pred.conf_int(alpha = 0.05) 
y_pred = SARIMAmodel.get_forecast(len(data_test.index)+21)
y_pred_df = y_pred.conf_int(alpha = 0.05) 
y_pred_df["Predictions"] = SARIMAmodel.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1]+ timedelta(days=21))
#y_pred_df.index = data_test.index
y_pred_out = y_pred_df["Predictions"]

# %%
y_pred_df
# Out:
#             lower UNITS_SOLD  upper UNITS_SOLD  Predictions
# 2021-07-16         22.881641         94.645541    58.763591
# 2021-07-17         16.130793        108.683105    62.406949
# 2021-07-18         13.020763        123.821643    68.421203
# 2021-07-19         -1.355479        124.866793    61.755657
# 2021-07-20        -14.134534        125.856861    55.861163
# ...                      ...               ...          ...
# 2021-11-29       -288.476558        420.913397    66.218419
# 2021-11-30       -297.477866        414.489846    58.505990
# 2021-12-01       -282.578156        431.958014    74.689929
# 2021-12-02       -253.419930        463.675498   105.127784
# 2021-12-03       -261.878947        457.766638    97.943846
#
# [141 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(9, 4))
data_train['UNITS_SOLD'].plot(ax=ax, label='train')
data_test['UNITS_SOLD'].plot(ax=ax, label='test')
y_pred_out.plot(ax=ax, label='predictions')
ax.legend();

# %%
arma_rmse = np.sqrt(mean_squared_error(data_test["UNITS_SOLD"].values, y_pred_df[y_pred_df.index.isin(data_test.index)]["Predictions"]))
print("RMSE: ",arma_rmse)
# Out:
# RMSE:  23.307790469429367

# %% [markdown]
# ### CATEG-2

# %%
df_2 = df_2.sort_index(ascending=True)

# %%
df_2.shape
# Out:
# (879, 1)

# %%
df_2.head(10)
# Out:
#             UNITS_SOLD
# DATE
# 2018-10-16           1
# 2019-06-11          15
# 2019-06-12          13
# 2019-06-13           8
# 2019-06-14           9
# 2019-06-15           9
# 2019-06-16           7
# 2019-06-17          15
# 2019-06-18          17
# 2019-06-19          11

# %%
df_2.tail(10)
# Out:
#             UNITS_SOLD
# DATE
# 2021-11-03          17
# 2021-11-04          14
# 2021-11-05          18
# 2021-11-06          17
# 2021-11-07          13
# 2021-11-08          21
# 2021-11-09          13
# 2021-11-10          18
# 2021-11-11          20
# 2021-11-12          12

# %%
df_2 = df_2.loc['2019-06-11':'2021-11-12']
df_2.shape
# Out:
# (878, 1)

# %% [markdown]
# Hay 8 dias que no estan en la serie,entonces los vamos a añadir con el valor de NA

# %%
dias_faltan = sorted(list(set(df_2.resample('D').mean().index) - set(df_2.index)))
dias_faltan
# Out:
# [Timestamp('2019-08-14 00:00:00', freq='D'),
#  Timestamp('2019-08-15 00:00:00', freq='D'),
#  Timestamp('2019-08-16 00:00:00', freq='D'),
#  Timestamp('2019-08-17 00:00:00', freq='D'),
#  Timestamp('2019-08-18 00:00:00', freq='D'),
#  Timestamp('2019-08-19 00:00:00', freq='D'),
#  Timestamp('2019-08-20 00:00:00', freq='D'),
#  Timestamp('2019-10-26 00:00:00', freq='D')]

# %%
add_days = pd.Series([np.nan]*len(dias_faltan), index = dias_faltan).to_frame()
add_days.rename(columns={0: 'UNITS_SOLD'})
df_2= pd.concat([df_2,add_days])
df_2 = df_2[['UNITS_SOLD']]
df_2 = df_2.sort_index(ascending=True)

# %%
df_2.set_index(df_2.resample('D').mean().index,inplace=True,drop=True)

# %% [markdown]
# Comprobamos que la longitud de la serie coincida con la cantidad de dias entre las fechas de inicio y final de la misma

# %%
f_date = date(2019, 6, 11)
l_date = date(2021, 11, 12)
delta = l_date - f_date
print(delta.days)
# Out:
# 885

# %%
df_2.shape
# Out:
# (886, 1)

# %%
#df_2 = df_2.loc['2019-10-27':'2021-11-12']

# %%
plt.rcParams['font.size'] = '8'
plt.xticks(rotation=90)
plt.plot(df_2.UNITS_SOLD)

# %%
plt.rcParams['font.size'] = '8'
plt.xticks(rotation=90)
plt.plot(df_2.UNITS_SOLD-df_2.UNITS_SOLD.shift(1))

# %%
plot_acf(df_2.loc['2019-10-27':'2021-11-12'])
pyplot.show()

# %%
plot_pacf(df_2.loc['2019-10-27':'2021-11-12'], lags=30)
pyplot.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
steps = 120
data_train = df_2[:-steps]
data_test  = df_2[-steps:]

print(f"Train dates : {data_train.index.min()} --- {data_train.index.max()}  (n={len(data_train)})")
print(f"Test dates  : {data_test.index.min()} --- {data_test.index.max()}  (n={len(data_test)})")

fig, ax=plt.subplots(figsize=(9, 4))
data_train['UNITS_SOLD'].plot(ax=ax, label='train')
data_test['UNITS_SOLD'].plot(ax=ax, label='test')
ax.legend();
# Out:
# Train dates : 2019-06-11 00:00:00 --- 2021-07-15 00:00:00  (n=766)
# Test dates  : 2021-07-16 00:00:00 --- 2021-11-12 00:00:00  (n=120)

# %%
SARIMAmodel = SARIMAX(data_train, order = (1, 1, 0),seasonal_order=(1,1,0,180)) 
SARIMAmodel = SARIMAmodel.fit()

# %%
y_pred = SARIMAmodel.get_forecast(len(data_test.index)+21)
y_pred_df = y_pred.conf_int(alpha = 0.05) 
y_pred = SARIMAmodel.get_forecast(len(data_test.index)+21)
y_pred_df = y_pred.conf_int(alpha = 0.05) 
y_pred_df["Predictions"] = SARIMAmodel.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1]+ timedelta(days=21))
#y_pred_df.index = data_test.index
y_pred_out = y_pred_df["Predictions"]

# %%
fig, ax = plt.subplots(figsize=(9, 4))
data_train['UNITS_SOLD'].plot(ax=ax, label='train')
data_test['UNITS_SOLD'].plot(ax=ax, label='test')
y_pred_out.plot(ax=ax, label='predictions')
ax.legend();

# %%
arma_rmse = np.sqrt(mean_squared_error(data_test["UNITS_SOLD"].values, y_pred_df[y_pred_df.index.isin(data_test.index)]["Predictions"]))
print("RMSE: ",arma_rmse)
# Out:
# RMSE:  26.23836558849234

# %% [markdown]
# ### CATEG-3

# %%
df_3 = df_3.sort_index(ascending=True)

# %%
df_3.shape
# Out:
# (920, 1)

# %%
df_3.head(10)
# Out:
#             UNITS_SOLD
# DATE
# 2018-09-24           0
# 2018-09-25           0
# 2018-09-27           0
# 2018-09-28           2
# 2018-09-29           1
# 2018-09-30           1
# 2018-10-01           2
# 2018-10-02           1
# 2018-10-03           2
# 2018-10-04           0

# %%
df_3.tail(10)
# Out:
#             UNITS_SOLD
# DATE
# 2021-11-03        2065
# 2021-11-04        2618
# 2021-11-05        2929
# 2021-11-06        2751
# 2021-11-07        2576
# 2021-11-08        2812
# 2021-11-09        2894
# 2021-11-10        7551
# 2021-11-11        6294
# 2021-11-12        3829

# %%
dias_faltan = sorted(list(set(df_3.resample('D').mean().index) - set(df_3.index)))
dias_faltan
# Out:
# [Timestamp('2018-09-26 00:00:00', freq='D'),
#  Timestamp('2018-10-16 00:00:00', freq='D'),
#  Timestamp('2018-10-17 00:00:00', freq='D'),
#  Timestamp('2018-10-26 00:00:00', freq='D'),
#  Timestamp('2018-10-27 00:00:00', freq='D'),
#  Timestamp('2018-10-28 00:00:00', freq='D'),
#  Timestamp('2018-10-30 00:00:00', freq='D'),
#  Timestamp('2018-10-31 00:00:00', freq='D'),
#  Timestamp('2018-11-01 00:00:00', freq='D'),
#  Timestamp('2018-11-02 00:00:00', freq='D'),
#  Timestamp('2018-11-04 00:00:00', freq='D'),
#  Timestamp('2018-11-06 00:00:00', freq='D'),
#  Timestamp('2018-11-07 00:00:00', freq='D'),
#  Timestamp('2018-11-09 00:00:00', freq='D'),
#  Timestamp('2018-11-10 00:00:00', freq='D'),
#  Timestamp('2018-11-12 00:00:00', freq='D'),
#  Timestamp('2018-11-13 00:00:00', freq='D'),
#  Timestamp('2018-11-14 00:00:00', freq='D'),
#  Timestamp('2018-11-15 00:00:00', freq='D'),
#  Timestamp('2018-11-16 00:00:00', freq='D'),
#  Timestamp('2018-11-17 00:00:00', freq='D'),
#  Timestamp('2018-11-18 00:00:00', freq='D'),
#  Timestamp('2018-11-19 00:00:00', freq='D'),
#  Timestamp('2018-11-20 00:00:00', freq='D'),
#  Timestamp('2018-11-21 00:00:00', freq='D'),
#  Timestamp('2018-11-22 00:00:00', freq='D'),
#  Timestamp('2018-11-23 00:00:00', freq='D'),
#  Timestamp('2018-11-24 00:00:00', freq='D'),
#  Timestamp('2018-11-25 00:00:00', freq='D'),
#  Timestamp('2018-11-26 00:00:00', freq='D'),
#  Timestamp('2018-11-27 00:00:00', freq='D'),
#  Timestamp('2018-11-28 00:00:00', freq='D'),
#  Timestamp('2018-11-29 00:00:00', freq='D'),
#  Timestamp('2018-11-30 00:00:00', freq='D'),
#  Timestamp('2018-12-01 00:00:00', freq='D'),
#  Timestamp('2018-12-02 00:00:00', freq='D'),
#  Timestamp('2018-12-03 00:00:00', freq='D'),
#  Timestamp('2018-12-04 00:00:00', freq='D'),
#  Timestamp('2018-12-05 00:00:00', freq='D'),
#  Timestamp('2018-12-06 00:00:00', freq='D'),
#  Timestamp('2018-12-07 00:00:00', freq='D'),
#  Timestamp('2018-12-08 00:00:00', freq='D'),
#  Timestamp('2018-12-09 00:00:00', freq='D'),
#  Timestamp('2018-12-10 00:00:00', freq='D'),
#  Timestamp('2018-12-11 00:00:00', freq='D'),
#  Timestamp('2018-12-12 00:00:00', freq='D'),
#  Timestamp('2019-05-25 00:00:00', freq='D'),
#  Timestamp('2019-05-26 00:00:00', freq='D'),
#  Timestamp('2019-05-27 00:00:00', freq='D'),
#  Timestamp('2019-05-28 00:00:00', freq='D'),
#  Timestamp('2019-05-29 00:00:00', freq='D'),
#  Timestamp('2019-05-30 00:00:00', freq='D'),
#  Timestamp('2019-05-31 00:00:00', freq='D'),
#  Timestamp('2019-06-01 00:00:00', freq='D'),
#  Timestamp('2019-06-02 00:00:00', freq='D'),
#  Timestamp('2019-06-03 00:00:00', freq='D'),
#  Timestamp('2019-06-04 00:00:00', freq='D'),
#  Timestamp('2019-06-05 00:00:00', freq='D'),
#  Timestamp('2019-06-06 00:00:00', freq='D'),
#  Timestamp('2019-06-07 00:00:00', freq='D'),
#  Timestamp('2019-06-08 00:00:00', freq='D'),
#  Timestamp('2019-06-09 00:00:00', freq='D'),
#  Timestamp('2019-06-10 00:00:00', freq='D')]

# %%
len(dias_faltan)
# Out:
# 226

# %%
df_3 = df_3.loc['2018-09-24':'2021-11-12']
df_3.shape
# Out:
# (920, 1)

# %%
add_days = pd.Series([np.nan]*len(dias_faltan), index = dias_faltan).to_frame()
add_days.rename(columns={0: 'UNITS_SOLD'})
df_3= pd.concat([df_3,add_days])
df_3 = df_3[['UNITS_SOLD']]
df_3 = df_3.sort_index(ascending=True)

# %%
df_3.set_index(df_3.resample('D').mean().index,inplace=True,drop=True)

# %%
f_date = date(2018, 9, 24)
l_date = date(2021, 11, 12)
delta = l_date - f_date
print(delta.days)
# Out:
# 1145

# %%
plt.rcParams['font.size'] = '8'
plt.xticks(rotation=90)
plt.plot(df_3.UNITS_SOLD)

# %%
df_3 = df_3.loc['2019-06-11':'2021-11-12']
df_3.shape
# Out:
# (886, 1)

# %%
plt.rcParams['font.size'] = '8'
plt.xticks(rotation=90)
plt.plot(df_3.UNITS_SOLD-df_3.UNITS_SOLD.shift(1))

# %%
plot_acf(df_3)
pyplot.show()

# %%
plot_pacf(df_3, lags=30)
pyplot.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
steps = 120
data_train = df_3[:-steps]
data_test  = df_3[-steps:]

print(f"Train dates : {data_train.index.min()} --- {data_train.index.max()}  (n={len(data_train)})")
print(f"Test dates  : {data_test.index.min()} --- {data_test.index.max()}  (n={len(data_test)})")

fig, ax=plt.subplots(figsize=(9, 4))
data_train['UNITS_SOLD'].plot(ax=ax, label='train')
data_test['UNITS_SOLD'].plot(ax=ax, label='test')
ax.legend();
# Out:
# Train dates : 2019-06-11 00:00:00 --- 2021-07-15 00:00:00  (n=766)
# Test dates  : 2021-07-16 00:00:00 --- 2021-11-12 00:00:00  (n=120)

# %%
SARIMAmodel = SARIMAX(data_train, order = (1, 1, 0), seasonal_order=(1,1,0,180)) 
SARIMAmodel = SARIMAmodel.fit()

# %%
y_pred = SARIMAmodel.get_forecast(len(data_test.index)+21)
y_pred_df = y_pred.conf_int(alpha = 0.05) 
y_pred = SARIMAmodel.get_forecast(len(data_test.index)+21)
y_pred_df = y_pred.conf_int(alpha = 0.05) 
y_pred_df["Predictions"] = SARIMAmodel.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1]+ timedelta(days=21))
#y_pred_df.index = data_test.index
y_pred_out = y_pred_df["Predictions"]

# %%
fig, ax = plt.subplots(figsize=(9, 4))
data_train['UNITS_SOLD'].plot(ax=ax, label='train')
data_test['UNITS_SOLD'].plot(ax=ax, label='test')
y_pred_out.plot(ax=ax, label='predictions')
ax.legend();

# %%
arma_rmse = np.sqrt(mean_squared_error(data_test["UNITS_SOLD"].values, y_pred_df[y_pred_df.index.isin(data_test.index)]["Predictions"]))
print("RMSE: ",arma_rmse)
# Out:
# RMSE:  601.9649168532607
